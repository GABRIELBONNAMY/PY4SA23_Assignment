# %% [markdown]
# # Lab Assignment 2 - Gabriel Bonnamy

# %% [markdown]
# ## Student code: 200000794

# %% [markdown]
# ### https://github.com/GABRIELBONNAMY/PY4SA23_Assignment.git

# %% [markdown]
# #### Python Basics

# %% [markdown]
# ##### Make sure all questions and answers are clearly labelled. The only python module that is required for this assignment is themath module

# %% [markdown]
# ##### Task 1: Create an If...Else statement that will test whether a number is divisible by three.

# %%
x = 7
if x % 3 == 0:
    print(x, 'is divisible by 3')
else:
    print(x, 'is not divisible by three')
# Out:
# 7 is not divisible by three

# %% [markdown]
# #### T2: Create an If...Else statement that will test whether a type of fruit, represented as a text string, is in a list of acceptable fruits (apple, orange, pear, kiwi, or strawberry)

# %%
mylist_fruits = ["apple", "orange", "pear", "kiwi", "strawberry"]
x = "tomato"
if x in mylist_fruits:
    print(x, 'is acceptable.')
else:
    print(x, 'is not acceptable.')
# Out:
# tomato is not acceptable.

# %% [markdown]
# #### T3: Create a function to calculate the distance between two coordinates using the haversine formula. Write the following formula where the input parameters are a pair of coordinates as two lists. haversine(θ) = sin²(θ/2).
# ##### The following equation where φ is latitude, λ is longitude, R is earth’s radius (mean radius = 6,371km) is how we translate the above formula to include latitude and longitude coordinates (A and B are the pair of coordinates). Note that angles need to be in radians to pass to trig functions:
# ##### a = sin²(φB - φA/2) + cos φA * cos φB * sin²(λB - λA/2)
# ##### c = 2 * atan2( √a, √(1−a) )
# ##### d = R ⋅ c

# %%
from math import radians, cos, asin, tan, sqrt

def haversine(Alat, Alon, Blat, Blon):
    # Calculate the great-circle distance (in km) between two points
    # using their longitude and latitude (in radians).
    # Radius of the Earth
    R = 6371.0

    # Convert degrees to radians
    # First Point
    Alat = radians(Alat)
    Alon = radians(Alon)

    # Second point
    Blat = radians(Blat)
    Blon = radians(Blon)

    # Haversine formula
    dlon = Blon - Alon
    dlat = Blat - Alat
    a = sin(dlat / 2)**2 + cos(Alat) * cos(Blat) * sin(dlon / 2)**2
    c = 2 * asin(sqrt(a))
    return R * c

Alat = 56.6
Alon = -3.0
Blat = 56.3
Blon = -2.8

print(haversine(Alat, Alon, Blat, Blon))
# Out:
# 35.55061864351124

# %% [markdown]
# ### Pandas and NumPy

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/Users/gabrielbonnamy/Documents/PY4SA23_Assignment/portland_park_trees.csv')

# %% [markdown]
# ##### Q1: How many trees are of the Quercus or Acer genus?

# %%
df.query('Genus == "Quercus" or Genus == "Acer"')
# Out:
#          fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  \
# 3          4       429  2017/05/09    QURU  10.3      Poor        28.0
# 11        12       437  2017/05/09    QURU  14.9      Fair        48.0
# 24        25       450  2017/05/15    ACGR   6.6      Fair        19.0
# 25        26       451  2017/05/15    ACGR   6.2      Fair        27.0
# 30        31       456  2017/05/15    ACPL  17.3      Fair        44.0
# ...      ...       ...         ...     ...   ...       ...         ...
# 25506  25507    724045  2019/10/11    ACMA  63.0      Poor        46.0
# 25508  25509    724047  2019/10/11    ACMA  35.0      Fair        57.0
# 25511  25512    724444  2019/10/11    ACMA  38.4      Fair       102.0
# 25516  25517    724843  2019/10/11    ACMA  19.0      Fair        64.0
# 25529  25530    726046  2018/08/16    QURU  31.6      Fair        74.0
#
#        CrownWidth  CrownWid_1 CollectedB  ...    Genus        Common_nam  \
# ...

# %% [markdown]
# ##### 5675 trees are of the Quercus or Acer genus.

# %% [markdown]
# ##### Q2: How many trees are of the Quercus or Acer genus and have a DBH larger than 50 inches?

# %%
subset_query = df.query('Genus == "Quercus" or Genus == "Acer"')

subset_query df.query1(DBH > 50)
# Out:
#   Cell In[59], line 2
#     in subset_query df.query1(DBH > 50)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Q3: Which genus has the highest mean DBH of the following genera: Quercus, Acer, or Fraxinus?
